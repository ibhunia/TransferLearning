# %%
from PIL import Image

# %%
im = Image.open('cat_or_dog_1.jpg')

# %%
type(im)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
im.show()

# %%
im.crop((50,50,400,400))
# Out:
# <PIL.Image.Image image mode=RGB size=350x350 at 0x2C4EFCB3388>

# %%
im.rotate(45, expand=True)
# Out:
# <PIL.Image.Image image mode=RGB size=1188x1188 at 0x2C4EF912B48>

# %%
im.resize((100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x2C4EF946708>

# %%
Image.ROTATE_90
# Out:
# 2

# %%
im.transpose(Image.ROTATE_90)
# Out:
# <PIL.Image.Image image mode=RGB size=720x960 at 0x2C4EFA82208>

# %%
im.size
# Out:
# (960, 720)

# %%
im.height
# Out:
# 720

# %%
im.width
# Out:
# 960

# %%
im.format
# Out:
# 'JPEG'

# %%
im.save('new.png')

# %%
from keras.preprocessing import image

# %%
kim = image.load_img('cat_or_dog_1.jpg', target_size=(200,200))

# %%
type(kim)
# Out:
# PIL.Image.Image

# %%
kim.size
# Out:
# (200, 200)
